# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Load in csv files
df_stations = pd.read_csv("df_stations.csv")

# %%
fs_df = pd.read_csv("fs_df_with_totals.csv")

# %%
df_stations.head(1)
# Out:
#    Empty Slots  Available Bikes                        Station ID   latitude  \
# 0           16               19  7a19c49f486d7c0c02b3685d7b240448  49.262487
#
#     longitude        Station Name    Data Collection Timestamp  Total Slots  \
# 0 -123.114397  0001 10th & Cambie  2022-11-06T21:18:12.713000Z           35
#
#    Status
# 0  online

# %%
#Rearrange columns for readability
cols = list(df_stations.columns.values)
print(cols)
# Out:
# ['Empty Slots', 'Available Bikes', 'Station ID', 'latitude', 'longitude', 'Station Name', 'Data Collection Timestamp', 'Total Slots', 'Status']

# %%
df_stations = df_stations[['Station ID', 'Station Name', 'latitude', 'longitude', 'Empty Slots', 'Available Bikes', 'Total Slots']]
df_stations.head(1)
# Out:
#                          Station ID        Station Name   latitude  \
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie  49.262487
#
#     longitude  Empty Slots  Available Bikes  Total Slots
# 0 -123.114397           16               19           35

# %%
df_stations["Proportion of Available Bikes (%)"] = round(df_stations["Available Bikes"] / df_stations["Total Slots"] * 100,0)
df_stations.head(2)
# Out:
#                          Station ID                      Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie
# 1  32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station
#
#     latitude   longitude  Empty Slots  Available Bikes  Total Slots  \
# 0  49.262487 -123.114397           16               19           35
# 1  49.274566 -123.121817            3               13           16
#
#    Proportion of Available Bikes (%)
# 0                               54.0
# 1                               81.0

# %%
fs_df.head(2)
# Out:
#                          Station ID   latitude   longitude  Bars - All  \
# 0  7a19c49f486d7c0c02b3685d7b240448  49.262487 -123.114397           1
# 1  32603a87cfca71d0f7dfa3513bad69d5  49.274566 -123.121817           7
#
#    Bars - Open  Restaurants - All  Restaurants - Open  Shopping - All  \
# 0            1                  7                   3               4
# 1            2                 25                  15              23
#
#    Shopping - Open  Education - All  Education - Open  \
# 0                1                1                 1
# 1               10                2                 0
#
#    Arts and Entertainment - All  Arts and Entertainment - Open  \
# 0                             1                              0
# 1                             3                              0
#
#    Total - All Venues  Total - Open Venues
# 0                  14                    6
# 1                  60                   27

# %%
fs_df = fs_df.drop(labels=["latitude", "longitude"], axis=1)
fs_df.head(2)
# Out:
#                          Station ID  Bars - All  Bars - Open  \
# 0  7a19c49f486d7c0c02b3685d7b240448           1            1
# 1  32603a87cfca71d0f7dfa3513bad69d5           7            2
#
#    Restaurants - All  Restaurants - Open  Shopping - All  Shopping - Open  \
# 0                  7                   3               4                1
# 1                 25                  15              23               10
#
#    Education - All  Education - Open  Arts and Entertainment - All  \
# 0                1                 1                             1
# 1                2                 0                             3
#
#    Arts and Entertainment - Open  Total - All Venues  Total - Open Venues
# 0                              0                  14                    6
# 1                              0                  60                   27

# %%
#Create combined df
df_combined = df_stations.merge(fs_df, on="Station ID", how='left')
df_combined.head(2)
# Out:
#                          Station ID                      Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie
# 1  32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station
#
#     latitude   longitude  Empty Slots  Available Bikes  Total Slots  \
# 0  49.262487 -123.114397           16               19           35
# 1  49.274566 -123.121817            3               13           16
#
#    Proportion of Available Bikes (%)  Bars - All  Bars - Open  \
# 0                               54.0           1            1
# 1                               81.0           7            2
#
#    Restaurants - All  Restaurants - Open  Shopping - All  Shopping - Open  \
# 0                  7                   3               4                1
# 1                 25                  15              23               10
#
#    Education - All  Education - Open  Arts and Entertainment - All  \
# 0                1                 1                             1
# 1                2                 0                             3
#
#    Arts and Entertainment - Open  Total - All Venues  Total - Open Venues
# 0                              0                  14                    6
# 1                              0                  60                   27

# %%
#look at distribution of total number of open businesses.
fig, ax = plt.subplots()
ax.hist(df_combined["Total - Open Venues"], bins = 10)

#Customize plot
ax.set_title("Histogram of Open Venues")
ax.set_xlabel("Number of Open Venues")
ax.set_ylabel('Counts')

#Displat the plot
plt.show()

# %%
#look at distribution of total number of businesses (open and closed).
fig, ax = plt.subplots()
ax.hist(df_combined["Total - All Venues"])

#Customize plot
ax.set_title("Histogram of All Venues")
ax.set_xlabel("Number of All Venues")
ax.set_ylabel('Counts')

#Displat the plot
plt.show()

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
#Create df of columns to look at correlation for open venues. 

open_correlation_df = df_combined[['Empty Slots', 'Available Bikes', 'Total Slots', 'Proportion of Available Bikes (%)', 'Bars - Open', 'Restaurants - Open', 'Shopping - Open', 'Education - Open', 'Arts and Entertainment - Open', 'Total - Open Venues']]
open_correlation_df.head(2)
# Out:
#    Empty Slots  Available Bikes  Total Slots  \
# 0           16               19           35
# 1            3               13           16
#
#    Proportion of Available Bikes (%)  Bars - Open  Restaurants - Open  \
# 0                               54.0            1                   3
# 1                               81.0            2                  15
#
#    Shopping - Open  Education - Open  Arts and Entertainment - Open  \
# 0                1                 1                              0
# 1               10                 0                              0
#
#    Total - Open Venues
# 0                    6
# 1                   27

# %%
open_correlation_df.corr()
# Out:
#                                    Empty Slots  Available Bikes  Total Slots  \
# Empty Slots                           1.000000        -0.585173     0.459997
# Available Bikes                      -0.585173         1.000000     0.449937
# Total Slots                           0.459997         0.449937     1.000000
# Proportion of Available Bikes (%)    -0.830402         0.881784     0.050182
# Bars - Open                           0.014140         0.132850     0.162550
# Restaurants - Open                    0.073605         0.115309     0.205088
# Shopping - Open                       0.072694         0.064790     0.148333
# Education - Open                      0.037153         0.107933     0.157118
# Arts and Entertainment - Open        -0.015069         0.052875     0.039286
# Total - Open Venues                   0.077762         0.112410     0.205958
#
#                                    Proportion of Available Bikes (%)  \
# Empty Slots                                                -0.830402
# Available Bikes                                             0.881784
# Total Slots                                                 0.050182
# Proportion of Available Bikes (%)                           1.000000
# Bars - Open                                                 0.041301
# Restaurants - Open                                          0.012426
# Shopping - Open                                            -0.008317
# Education - Open                                            0.027361
# Arts and Entertainment - Open                               0.027331
# Total - Open Venues                                         0.008527
#
#                                    Bars - Open  Restaurants - Open  \
# Empty Slots                           0.014140            0.073605
# Available Bikes                       0.132850            0.115309
# Total Slots                           0.162550            0.205088
# Proportion of Available Bikes (%)     0.041301            0.012426
# Bars - Open                           1.000000            0.534496
# Restaurants - Open                    0.534496            1.000000
# Shopping - Open                       0.370787            0.576107
# Education - Open                      0.434191            0.267722
# Arts and Entertainment - Open         0.172569            0.154172
# Total - Open Venues                   0.572747            0.867617
#
#                                    Shopping - Open  Education - Open  \
# Empty Slots                               0.072694          0.037153
# Available Bikes                           0.064790          0.107933
# Total Slots                               0.148333          0.157118
# Proportion of Available Bikes (%)        -0.008317          0.027361
# Bars - Open                               0.370787          0.434191
# Restaurants - Open                        0.576107          0.267722
# Shopping - Open                           1.000000          0.275171
# Education - Open                          0.275171          1.000000
# Arts and Entertainment - Open             0.234560          0.151315
# Total - Open Venues                       0.889915          0.394671
#
#                                    Arts and Entertainment - Open  \
# Empty Slots                                            -0.015069
# Available Bikes                                         0.052875
# Total Slots                                             0.039286
# Proportion of Available Bikes (%)                       0.027331
# Bars - Open                                             0.172569
# Restaurants - Open                                      0.154172
# Shopping - Open                                         0.234560
# Education - Open                                        0.151315
# Arts and Entertainment - Open                           1.000000
# Total - Open Venues                                     0.312217
#
#                                    Total - Open Venues
# Empty Slots                                   0.077762
# Available Bikes                               0.112410
# Total Slots                                   0.205958
# Proportion of Available Bikes (%)             0.008527
# Bars - Open                                   0.572747
# Restaurants - Open                            0.867617
# Shopping - Open                               0.889915
# Education - Open                              0.394671
# Arts and Entertainment - Open                 0.312217
# Total - Open Venues                           1.000000

# %%
#Subset for useful correlation info
#open venues
relevant_open_corr_df = open_correlation_df.corr().iloc[4:,0:4]
relevant_open_corr_df
# Out:
#                                Empty Slots  Available Bikes  Total Slots  \
# Bars - Open                       0.014140         0.132850     0.162550
# Restaurants - Open                0.073605         0.115309     0.205088
# Shopping - Open                   0.072694         0.064790     0.148333
# Education - Open                  0.037153         0.107933     0.157118
# Arts and Entertainment - Open    -0.015069         0.052875     0.039286
# Total - Open Venues               0.077762         0.112410     0.205958
#
#                                Proportion of Available Bikes (%)
# Bars - Open                                             0.041301
# Restaurants - Open                                      0.012426
# Shopping - Open                                        -0.008317
# Education - Open                                        0.027361
# Arts and Entertainment - Open                           0.027331
# Total - Open Venues                                     0.008527

# %%
comb_cols = list(df_combined.columns.values)
print(comb_cols)
# Out:
# ['Station ID', 'Station Name', 'latitude', 'longitude', 'Empty Slots', 'Available Bikes', 'Total Slots', 'Proportion of Available Bikes (%)', 'Bars - All', 'Bars - Open', 'Restaurants - All', 'Restaurants - Open', 'Shopping - All', 'Shopping - Open', 'Education - All', 'Education - Open', 'Arts and Entertainment - All', 'Arts and Entertainment - Open', 'Total - All Venues', 'Total - Open Venues']

# %%
#Create df of columns to look at correlation for total venues. 

total_correlation_df = df_combined[['Empty Slots', 'Available Bikes', 'Total Slots', 'Proportion of Available Bikes (%)', 'Bars - All', 'Restaurants - All', 'Shopping - All', 'Education - All', 'Arts and Entertainment - All', 'Total - All Venues']]
total_correlation_df.head(2)
# Out:
#    Empty Slots  Available Bikes  Total Slots  \
# 0           16               19           35
# 1            3               13           16
#
#    Proportion of Available Bikes (%)  Bars - All  Restaurants - All  \
# 0                               54.0           1                  7
# 1                               81.0           7                 25
#
#    Shopping - All  Education - All  Arts and Entertainment - All  \
# 0               4                1                             1
# 1              23                2                             3
#
#    Total - All Venues
# 0                  14
# 1                  60

# %%
total_correlation_df.corr()
# Out:
#                                    Empty Slots  Available Bikes  Total Slots  \
# Empty Slots                           1.000000        -0.585173     0.459997
# Available Bikes                      -0.585173         1.000000     0.449937
# Total Slots                           0.459997         0.449937     1.000000
# Proportion of Available Bikes (%)    -0.830402         0.881784     0.050182
# Bars - All                           -0.014036         0.109498     0.103320
# Restaurants - All                     0.069169         0.124100     0.209036
# Shopping - All                        0.069722         0.111555     0.196034
# Education - All                       0.017603         0.092186     0.118620
# Arts and Entertainment - All         -0.001983         0.113878     0.119955
# Total - All Venues                    0.064012         0.137647     0.217969
#
#                                    Proportion of Available Bikes (%)  \
# Empty Slots                                                -0.830402
# Available Bikes                                             0.881784
# Total Slots                                                 0.050182
# Proportion of Available Bikes (%)                           1.000000
# Bars - All                                                  0.049570
# Restaurants - All                                           0.024943
# Shopping - All                                              0.024792
# Education - All                                             0.030469
# Arts and Entertainment - All                                0.053340
# Total - All Venues                                          0.035580
#
#                                    Bars - All  Restaurants - All  \
# Empty Slots                         -0.014036           0.069169
# Available Bikes                      0.109498           0.124100
# Total Slots                          0.103320           0.209036
# Proportion of Available Bikes (%)    0.049570           0.024943
# Bars - All                           1.000000           0.633038
# Restaurants - All                    0.633038           1.000000
# Shopping - All                       0.428242           0.663658
# Education - All                      0.358479           0.369758
# Arts and Entertainment - All         0.428209           0.362238
# Total - All Venues                   0.621816           0.855498
#
#                                    Shopping - All  Education - All  \
# Empty Slots                              0.069722         0.017603
# Available Bikes                          0.111555         0.092186
# Total Slots                              0.196034         0.118620
# Proportion of Available Bikes (%)        0.024792         0.030469
# Bars - All                               0.428242         0.358479
# Restaurants - All                        0.663658         0.369758
# Shopping - All                           1.000000         0.503490
# Education - All                          0.503490         1.000000
# Arts and Entertainment - All             0.523881         0.317185
# Total - All Venues                       0.928630         0.614855
#
#                                    Arts and Entertainment - All  \
# Empty Slots                                           -0.001983
# Available Bikes                                        0.113878
# Total Slots                                            0.119955
# Proportion of Available Bikes (%)                      0.053340
# Bars - All                                             0.428209
# Restaurants - All                                      0.362238
# Shopping - All                                         0.523881
# Education - All                                        0.317185
# Arts and Entertainment - All                           1.000000
# Total - All Venues                                     0.587274
#
#                                    Total - All Venues
# Empty Slots                                  0.064012
# Available Bikes                              0.137647
# Total Slots                                  0.217969
# Proportion of Available Bikes (%)            0.035580
# Bars - All                                   0.621816
# Restaurants - All                            0.855498
# Shopping - All                               0.928630
# Education - All                              0.614855
# Arts and Entertainment - All                 0.587274
# Total - All Venues                           1.000000

# %%
#Subset for useful correlation info
#total venues
relevant_total_corr_df = total_correlation_df.corr().iloc[4:,0:4]
relevant_total_corr_df
# Out:
#                               Empty Slots  Available Bikes  Total Slots  \
# Bars - All                      -0.014036         0.109498     0.103320
# Restaurants - All                0.069169         0.124100     0.209036
# Shopping - All                   0.069722         0.111555     0.196034
# Education - All                  0.017603         0.092186     0.118620
# Arts and Entertainment - All    -0.001983         0.113878     0.119955
# Total - All Venues               0.064012         0.137647     0.217969
#
#                               Proportion of Available Bikes (%)
# Bars - All                                             0.049570
# Restaurants - All                                      0.024943
# Shopping - All                                         0.024792
# Education - All                                        0.030469
# Arts and Entertainment - All                           0.053340
# Total - All Venues                                     0.035580

# %%
import seaborn as sns

# %%
sns.heatmap(relevant_open_corr_df)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(relevant_total_corr_df)
# Out:
# <AxesSubplot:>

# %%
#Hypotheses to test: 
#Larger bike stations are installed where there are more businesses within 100 m - use Pearson's Correlation Coefficient
#Larger bike stations are installed where there are more restaurants within 100 m - use Pearson's Correlation Coefficient

# %%
from scipy import stats

# %%
df_combined.head(1)
# Out:
#                          Station ID        Station Name   latitude  \
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie  49.262487
#
#     longitude  Empty Slots  Available Bikes  Total Slots  \
# 0 -123.114397           16               19           35
#
#    Proportion of Available Bikes (%)  Bars - All  Bars - Open  \
# 0                               54.0           1            1
#
#    Restaurants - All  Restaurants - Open  Shopping - All  Shopping - Open  \
# 0                  7                   3               4                1
#
#    Education - All  Education - Open  Arts and Entertainment - All  \
# 0                1                 1                             1
#
#    Arts and Entertainment - Open  Total - All Venues  Total - Open Venues
# 0                              0                  14                    6

# %%
#Set variables for hypothesis testing
total_slots = df_combined["Total Slots"]
total_venues = df_combined["Total - All Venues"]
total_restaurants = df_combined["Restaurants - All"]

# %%
#Check if any/all variables follow normal distributions. 
#Check using Shapiro-Wilk Tests
#Null hypothesis is that data is normally distributed
stat, p = stats.shapiro(total_slots)
if p >= 0.05:
    print("total_slots is normally distributed")
else:
    print("total_slots is not normally distributed")

stat, p = stats.shapiro(total_venues)
if p >= 0.05:
    print("total_venues is normally distributed")
else:
    print("total_venues is not normally distributed")

stat, p = stats.shapiro(total_restaurants)
if p >= 0.05:
    print("total_restaurants is normally distributed")
else:
    print("total_restaurants is not normally distributed")
# Out:
# total_slots is not normally distributed
# total_venues is not normally distributed
# total_restaurants is not normally distributed

# %%
#Test 1: 
#Are larger bike stations are installed where there are more businesses within 100 m
#Use Pearson's Correlation Coefficient

#Data to compare:
#Total slots - call list total_slots
#Number of total venues - total_venues
#Null hypothesis: total_slots and total_venues are NOT correlated.
#Pull this data from df_combined


stat, p = stats.pearsonr(total_slots, total_venues)
print(p)
# Out:
# 0.0006736131478174696

# %%
#p-value < 0.05, so can reject the null hypothesis. Variables are correlated. 
#However data is not normally distributed, so I'm not sure if this is very useful.

# %%
#Test 2: 
#Larger bike stations are installed where there are more restaurants within 100 m
#Use Pearson's Correlation Coefficient

stat, p = stats.pearsonr(total_slots, total_restaurants)
print(p)
# Out:
# 0.0011238692036927627

# %%
#p-value < 0.05, so can reject the null hypothesis. Variables are correlated. 
#However data is not normally distributed, so I'm not sure if this is very useful.

# %% [markdown]
# # Database

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %%
#Create 6 tables for database
#starting point for tables is: 
    #df_stations
        #split into station_locations and station_docks
    #fs_df
        #split into fs_venues and fs_venues_open
    #yelp_df
        #split into yelp_venues and yelp_venues_open

# %%
df_stations.head(2)
# Out:
#                          Station ID                      Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie
# 1  32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station
#
#     latitude   longitude  Empty Slots  Available Bikes  Total Slots  \
# 0  49.262487 -123.114397           16               19           35
# 1  49.274566 -123.121817            3               13           16
#
#    Proportion of Available Bikes (%)
# 0                               54.0
# 1                               81.0

# %%
fs_df.head(2)
# Out:
#                          Station ID  Bars - All  Bars - Open  \
# 0  7a19c49f486d7c0c02b3685d7b240448           1            1
# 1  32603a87cfca71d0f7dfa3513bad69d5           7            2
#
#    Restaurants - All  Restaurants - Open  Shopping - All  Shopping - Open  \
# 0                  7                   3               4                1
# 1                 25                  15              23               10
#
#    Education - All  Education - Open  Arts and Entertainment - All  \
# 0                1                 1                             1
# 1                2                 0                             3
#
#    Arts and Entertainment - Open  Total - All Venues  Total - Open Venues
# 0                              0                  14                    6
# 1                              0                  60                   27

# %%
#Import yelp df from stored csv
yelp_df = pd.read_csv("yelp_df_with_totals.csv")
yelp_df.head(2)
# Out:
#                          Station ID   latitude   longitude  Bars - All  \
# 0  7a19c49f486d7c0c02b3685d7b240448  49.262487 -123.114397           0
# 1  32603a87cfca71d0f7dfa3513bad69d5  49.274566 -123.121817           7
#
#    Bars - Open  Restaurants - All  Restaurants - Open  Shopping - All  \
# 0            0                  9                   7               4
# 1            4                 23                  17               8
#
#    Shopping - Open  Education - All  Education - Open  \
# 0                1                0                 0
# 1                8                1                 1
#
#    Arts and Entertainment - All  Arts and Entertainment - Open  \
# 0                             1                              1
# 1                             2                              1
#
#    Total - All Venues  Total - Open Venues
# 0                  14                    8
# 1                  41                   31

# %%
#Split df_stations into station_locations and station_docks
df_stations_col_list = list(df_stations.columns.values)
print(df_stations_col_list)
# Out:
# ['Station ID', 'Station Name', 'latitude', 'longitude', 'Empty Slots', 'Available Bikes', 'Total Slots', 'Proportion of Available Bikes (%)']

# %%
station_locations = df_stations[['Station ID', 'Station Name', 'latitude', 'longitude']]
station_docks = df_stations[['Station ID', 'Empty Slots', 'Available Bikes', 'Total Slots', 'Proportion of Available Bikes (%)']]

# %%
station_locations.head(2)
# Out:
#                          Station ID                      Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie
# 1  32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station
#
#     latitude   longitude
# 0  49.262487 -123.114397
# 1  49.274566 -123.121817

# %%
station_docks.head(2)
# Out:
#                          Station ID  Empty Slots  Available Bikes  \
# 0  7a19c49f486d7c0c02b3685d7b240448           16               19
# 1  32603a87cfca71d0f7dfa3513bad69d5            3               13
#
#    Total Slots  Proportion of Available Bikes (%)
# 0           35                               54.0
# 1           16                               81.0

# %%
#Split fs_df into fs_venues and fs_venues_open
fs_df_col_list = list(fs_df.columns.values)
print(fs_df_col_list)
# Out:
# ['Station ID', 'Bars - All', 'Bars - Open', 'Restaurants - All', 'Restaurants - Open', 'Shopping - All', 'Shopping - Open', 'Education - All', 'Education - Open', 'Arts and Entertainment - All', 'Arts and Entertainment - Open', 'Total - All Venues', 'Total - Open Venues']

# %%
fs_venues = fs_df[['Station ID', 'Bars - All', 'Restaurants - All', 'Shopping - All', 'Education - All', 'Arts and Entertainment - All', 'Total - All Venues']]
fs_venues_open = fs_df[['Station ID', 'Bars - Open', 'Restaurants - Open', 'Shopping - Open', 'Education - Open', 'Arts and Entertainment - Open', 'Total - Open Venues']]

# %%
fs_venues.head(2)
# Out:
#                          Station ID  Bars - All  Restaurants - All  \
# 0  7a19c49f486d7c0c02b3685d7b240448           1                  7
# 1  32603a87cfca71d0f7dfa3513bad69d5           7                 25
#
#    Shopping - All  Education - All  Arts and Entertainment - All  \
# 0               4                1                             1
# 1              23                2                             3
#
#    Total - All Venues
# 0                  14
# 1                  60

# %%
fs_venues_open.head(2)
# Out:
#                          Station ID  Bars - Open  Restaurants - Open  \
# 0  7a19c49f486d7c0c02b3685d7b240448            1                   3
# 1  32603a87cfca71d0f7dfa3513bad69d5            2                  15
#
#    Shopping - Open  Education - Open  Arts and Entertainment - Open  \
# 0                1                 1                              0
# 1               10                 0                              0
#
#    Total - Open Venues
# 0                    6
# 1                   27

# %%
#Split yelp_df into yelp_venues and yelp_venues_open
yelp_df_col_list = list(yelp_df.columns.values)
print(yelp_df_col_list)
# Out:
# ['Station ID', 'latitude', 'longitude', 'Bars - All', 'Bars - Open', 'Restaurants - All', 'Restaurants - Open', 'Shopping - All', 'Shopping - Open', 'Education - All', 'Education - Open', 'Arts and Entertainment - All', 'Arts and Entertainment - Open', 'Total - All Venues', 'Total - Open Venues']

# %%
yelp_venues = fs_df[['Station ID', 'Bars - All', 'Restaurants - All', 'Shopping - All', 'Education - All', 'Arts and Entertainment - All', 'Total - All Venues']]
yelp_venues_open = fs_df[['Station ID', 'Bars - Open', 'Restaurants - Open', 'Shopping - Open', 'Education - Open', 'Arts and Entertainment - Open', 'Total - Open Venues']]

# %%
yelp_venues.head(2)
# Out:
#                          Station ID  Bars - All  Restaurants - All  \
# 0  7a19c49f486d7c0c02b3685d7b240448           1                  7
# 1  32603a87cfca71d0f7dfa3513bad69d5           7                 25
#
#    Shopping - All  Education - All  Arts and Entertainment - All  \
# 0               4                1                             1
# 1              23                2                             3
#
#    Total - All Venues
# 0                  14
# 1                  60

# %%
yelp_venues_open.head(2)
# Out:
#                          Station ID  Bars - Open  Restaurants - Open  \
# 0  7a19c49f486d7c0c02b3685d7b240448            1                   3
# 1  32603a87cfca71d0f7dfa3513bad69d5            2                  15
#
#    Shopping - Open  Education - Open  Arts and Entertainment - Open  \
# 0                1                 1                              0
# 1               10                 0                              0
#
#    Total - Open Venues
# 0                    6
# 1                   27

# %%
station_locations = station_locations.set_index("Station ID")

# %%
#Set index for all tables: 

#station_locations
#station_docks

station_docks = station_docks.set_index("Station ID")

#fs_venues
#fs_venues_open
fs_venues = fs_venues.set_index("Station ID")
fs_venues_open = fs_venues_open.set_index("Station ID")

#yelp_venues
#yelp_venues_open
yelp_venues = yelp_venues.set_index("Station ID")
yelp_venues_open = yelp_venues_open.set_index("Station ID")

# %%
station_locations.head(2)
# Out:
#                                                       Station Name   latitude  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie  49.262487
# 32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station  49.274566
#
#                                    longitude
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448 -123.114397
# 32603a87cfca71d0f7dfa3513bad69d5 -123.121817

# %%
station_docks.head(2)
# Out:
#                                   Empty Slots  Available Bikes  Total Slots  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448           16               19           35
# 32603a87cfca71d0f7dfa3513bad69d5            3               13           16
#
#                                   Proportion of Available Bikes (%)
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                               54.0
# 32603a87cfca71d0f7dfa3513bad69d5                               81.0

# %%
fs_venues.head(2)
# Out:
#                                   Bars - All  Restaurants - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448           1                  7
# 32603a87cfca71d0f7dfa3513bad69d5           7                 25
#
#                                   Shopping - All  Education - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448               4                1
# 32603a87cfca71d0f7dfa3513bad69d5              23                2
#
#                                   Arts and Entertainment - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                             1
# 32603a87cfca71d0f7dfa3513bad69d5                             3
#
#                                   Total - All Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                  14
# 32603a87cfca71d0f7dfa3513bad69d5                  60

# %%
fs_venues_open.head(2)
# Out:
#                                   Bars - Open  Restaurants - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448            1                   3
# 32603a87cfca71d0f7dfa3513bad69d5            2                  15
#
#                                   Shopping - Open  Education - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                1                 1
# 32603a87cfca71d0f7dfa3513bad69d5               10                 0
#
#                                   Arts and Entertainment - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                              0
# 32603a87cfca71d0f7dfa3513bad69d5                              0
#
#                                   Total - Open Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                    6
# 32603a87cfca71d0f7dfa3513bad69d5                   27

# %%
yelp_venues.head(2)
# Out:
#                                   Bars - All  Restaurants - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448           1                  7
# 32603a87cfca71d0f7dfa3513bad69d5           7                 25
#
#                                   Shopping - All  Education - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448               4                1
# 32603a87cfca71d0f7dfa3513bad69d5              23                2
#
#                                   Arts and Entertainment - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                             1
# 32603a87cfca71d0f7dfa3513bad69d5                             3
#
#                                   Total - All Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                  14
# 32603a87cfca71d0f7dfa3513bad69d5                  60

# %%
yelp_venues_open.head(2)
# Out:
#                                   Bars - Open  Restaurants - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448            1                   3
# 32603a87cfca71d0f7dfa3513bad69d5            2                  15
#
#                                   Shopping - Open  Education - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                1                 1
# 32603a87cfca71d0f7dfa3513bad69d5               10                 0
#
#                                   Arts and Entertainment - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                              0
# 32603a87cfca71d0f7dfa3513bad69d5                              0
#
#                                   Total - Open Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                    6
# 32603a87cfca71d0f7dfa3513bad69d5                   27

# %%
import pandas as pd

# %%
#Save all dfs for db as csv. 
station_docks.to_csv("station_docks.csv")
fs_venues.to_csv("fs_venues.csv")
fs_venues_open.to_csv("fs_venues_open.csv")
yelp_venues.to_csv("yelp_venues.csv")
yelp_venues_open.to_csv("yelp_venues_open.csv")

# %%
station_locations = pd.read_csv("station_locations.csv")
station_docks = pd.read_csv("station_docks.csv")
fs_venues = pd.read_csv("fs_venues.csv")
fs_venues_open = pd.read_csv("fs_venues_open.csv")
yelp_venues = pd.read_csv("yelp_venues.csv")
yelp_venues_open = pd.read_csv("yelp_venues_open.csv")

# %%
import sqlite3
from sqlite3 import Error

def create_connection(path):
    connection = None
    try:
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")
        
    return connection

# %%
connection = create_connection("sm_app.sqlite")
# Out:
# Connection to SQLite DB successful

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
station_docks.to_sql("station_docks2", connection, if_exists="replace")
# Out:
# 240

# %%
connection.close()

# %%
con = sqlite3.connect("stats_project_db.sqlite")

# %%
station_docks.to_sql("station_docks", con, if_exists="replace")
# Out:
# 240

# %%
station_locations.to_sql("station_locations", con, if_exists="replace")
fs_venues.to_sql("fs_venues", con, if_exists="replace")
fs_venues_open.to_sql("fs_venues_open", con, if_exists="replace")
yelp_venues.to_sql("yelp_venues", con, if_exists="replace")
yelp_venues_open.to_sql("yelp_venues_open", con, if_exists="replace")
# Out:
# 240

# %%
add_key_query_docks = """
ALTER TABLE station_docks
ADD PRIMARY KEY (station_id);
"""

# %%
execute_query(con, add_key_query_docks)
# Out:
# The error 'near "PRIMARY": syntax error' occurred

# %%
fs_venues_open.head()
# Out:
#                                   Bars - Open  Restaurants - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448            1                   3
# 32603a87cfca71d0f7dfa3513bad69d5            2                  15
# 6d42fa40360f9a6b2bf641c7b8bb2862            1                   6
# 66f873d641d448bd1572ab086665a458            0                   0
# 485d4d24c803cfde829ab89699fed833            0                   4
#
#                                   Shopping - Open  Education - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                1                 1
# 32603a87cfca71d0f7dfa3513bad69d5               10                 0
# 6d42fa40360f9a6b2bf641c7b8bb2862                0                 0
# 66f873d641d448bd1572ab086665a458                0                 0
# 485d4d24c803cfde829ab89699fed833                2                 0
#
#                                   Arts and Entertainment - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                              0
# 32603a87cfca71d0f7dfa3513bad69d5                              0
# 6d42fa40360f9a6b2bf641c7b8bb2862                              0
# 66f873d641d448bd1572ab086665a458                              0
# 485d4d24c803cfde829ab89699fed833                              0
#
#                                   Total - Open Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                    6
# 32603a87cfca71d0f7dfa3513bad69d5                   27
# 6d42fa40360f9a6b2bf641c7b8bb2862                    7
# 66f873d641d448bd1572ab086665a458                    0
# 485d4d24c803cfde829ab89699fed833                    6

# %%
station_locations.head(1)
# Out:
#                          Station ID        Station Name   latitude   longitude
# 0  7a19c49f486d7c0c02b3685d7b240448  0001 10th & Cambie  49.262487 -123.114397

# %%
station_locations = station_locations.set_index("Station ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [207], in <cell line: 1>()
# ----> 1 station_locations = station_locations.set_index("Station ID")
#       2 station_locations.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['Station ID'] are in the columns"

# %%
station_locations.head()
# Out:
#                                                       Station Name   latitude  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie  49.262487
# 32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station  49.274566
# 6d42fa40360f9a6b2bf641c7b8bb2862            0005 Dunsmuir & Beatty  49.279764
# 66f873d641d448bd1572ab086665a458     0007 12th & Yukon (City Hall)  49.260599
# 485d4d24c803cfde829ab89699fed833                    0008 8th & Ash  49.264215
#
#                                    longitude
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448 -123.114397
# 32603a87cfca71d0f7dfa3513bad69d5 -123.121817
# 6d42fa40360f9a6b2bf641c7b8bb2862 -123.110154
# 66f873d641d448bd1572ab086665a458 -123.113504
# 485d4d24c803cfde829ab89699fed833 -123.117772

# %%
station_docks = station_docks.set_index("Station ID")

# %%
station_docks.head()
# Out:
#                                   Empty Slots  Available Bikes  Total Slots  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448           16               19           35
# 32603a87cfca71d0f7dfa3513bad69d5            3               13           16
# 6d42fa40360f9a6b2bf641c7b8bb2862            7               19           26
# 66f873d641d448bd1572ab086665a458           11                5           16
# 485d4d24c803cfde829ab89699fed833            8                8           16
#
#                                   Proportion of Available Bikes (%)
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                               54.0
# 32603a87cfca71d0f7dfa3513bad69d5                               81.0
# 6d42fa40360f9a6b2bf641c7b8bb2862                               73.0
# 66f873d641d448bd1572ab086665a458                               31.0
# 485d4d24c803cfde829ab89699fed833                               50.0

# %%
fs_venues = fs_venues.set_index("Station ID")

# %%
fs_venues.head()
# Out:
#                                   Bars - All  Restaurants - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448           1                  7
# 32603a87cfca71d0f7dfa3513bad69d5           7                 25
# 6d42fa40360f9a6b2bf641c7b8bb2862           1                  9
# 66f873d641d448bd1572ab086665a458           0                  1
# 485d4d24c803cfde829ab89699fed833           0                  8
#
#                                   Shopping - All  Education - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448               4                1
# 32603a87cfca71d0f7dfa3513bad69d5              23                2
# 6d42fa40360f9a6b2bf641c7b8bb2862               3                1
# 66f873d641d448bd1572ab086665a458               1                0
# 485d4d24c803cfde829ab89699fed833               7                7
#
#                                   Arts and Entertainment - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                             1
# 32603a87cfca71d0f7dfa3513bad69d5                             3
# 6d42fa40360f9a6b2bf641c7b8bb2862                             2
# 66f873d641d448bd1572ab086665a458                             0
# 485d4d24c803cfde829ab89699fed833                             0
#
#                                   Total - All Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                  14
# 32603a87cfca71d0f7dfa3513bad69d5                  60
# 6d42fa40360f9a6b2bf641c7b8bb2862                  16
# 66f873d641d448bd1572ab086665a458                   2
# 485d4d24c803cfde829ab89699fed833                  22

# %%
fs_venues_open.head()
# Out:
#                                   Bars - Open  Restaurants - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448            1                   3
# 32603a87cfca71d0f7dfa3513bad69d5            2                  15
# 6d42fa40360f9a6b2bf641c7b8bb2862            1                   6
# 66f873d641d448bd1572ab086665a458            0                   0
# 485d4d24c803cfde829ab89699fed833            0                   4
#
#                                   Shopping - Open  Education - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                1                 1
# 32603a87cfca71d0f7dfa3513bad69d5               10                 0
# 6d42fa40360f9a6b2bf641c7b8bb2862                0                 0
# 66f873d641d448bd1572ab086665a458                0                 0
# 485d4d24c803cfde829ab89699fed833                2                 0
#
#                                   Arts and Entertainment - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                              0
# 32603a87cfca71d0f7dfa3513bad69d5                              0
# 6d42fa40360f9a6b2bf641c7b8bb2862                              0
# 66f873d641d448bd1572ab086665a458                              0
# 485d4d24c803cfde829ab89699fed833                              0
#
#                                   Total - Open Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                    6
# 32603a87cfca71d0f7dfa3513bad69d5                   27
# 6d42fa40360f9a6b2bf641c7b8bb2862                    7
# 66f873d641d448bd1572ab086665a458                    0
# 485d4d24c803cfde829ab89699fed833                    6

# %%
yelp_venues.head()
# Out:
#                                   Bars - All  Restaurants - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448           1                  7
# 32603a87cfca71d0f7dfa3513bad69d5           7                 25
# 6d42fa40360f9a6b2bf641c7b8bb2862           1                  9
# 66f873d641d448bd1572ab086665a458           0                  1
# 485d4d24c803cfde829ab89699fed833           0                  8
#
#                                   Shopping - All  Education - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448               4                1
# 32603a87cfca71d0f7dfa3513bad69d5              23                2
# 6d42fa40360f9a6b2bf641c7b8bb2862               3                1
# 66f873d641d448bd1572ab086665a458               1                0
# 485d4d24c803cfde829ab89699fed833               7                7
#
#                                   Arts and Entertainment - All  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                             1
# 32603a87cfca71d0f7dfa3513bad69d5                             3
# 6d42fa40360f9a6b2bf641c7b8bb2862                             2
# 66f873d641d448bd1572ab086665a458                             0
# 485d4d24c803cfde829ab89699fed833                             0
#
#                                   Total - All Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                  14
# 32603a87cfca71d0f7dfa3513bad69d5                  60
# 6d42fa40360f9a6b2bf641c7b8bb2862                  16
# 66f873d641d448bd1572ab086665a458                   2
# 485d4d24c803cfde829ab89699fed833                  22

# %%
yelp_venues_open.head()
# Out:
#                                   Bars - Open  Restaurants - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448            1                   3
# 32603a87cfca71d0f7dfa3513bad69d5            2                  15
# 6d42fa40360f9a6b2bf641c7b8bb2862            1                   6
# 66f873d641d448bd1572ab086665a458            0                   0
# 485d4d24c803cfde829ab89699fed833            0                   4
#
#                                   Shopping - Open  Education - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                1                 1
# 32603a87cfca71d0f7dfa3513bad69d5               10                 0
# 6d42fa40360f9a6b2bf641c7b8bb2862                0                 0
# 66f873d641d448bd1572ab086665a458                0                 0
# 485d4d24c803cfde829ab89699fed833                2                 0
#
#                                   Arts and Entertainment - Open  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                              0
# 32603a87cfca71d0f7dfa3513bad69d5                              0
# 6d42fa40360f9a6b2bf641c7b8bb2862                              0
# 66f873d641d448bd1572ab086665a458                              0
# 485d4d24c803cfde829ab89699fed833                              0
#
#                                   Total - Open Venues
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                    6
# 32603a87cfca71d0f7dfa3513bad69d5                   27
# 6d42fa40360f9a6b2bf641c7b8bb2862                    7
# 66f873d641d448bd1572ab086665a458                    0
# 485d4d24c803cfde829ab89699fed833                    6

# %%
con.close()

# %%
con = sqlite3.connect("stats_project.sqlite")

# %%
station_docks.to_sql("station_docks", con, if_exists="replace")
station_locations.to_sql("station_locations", con, if_exists="replace")
fs_venues.to_sql("fs_venues", con, if_exists="replace")
fs_venues_open.to_sql("fs_venues_open", con, if_exists="replace")
yelp_venues.to_sql("yelp_venues", con, if_exists="replace")
yelp_venues_open.to_sql("yelp_venues_open", con, if_exists="replace")
# Out:
# 240

# %%
fk_docks_query = """
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;

    ALTER TABLE station_docks RENAME TO station_docks_old;

    CREATE TABLE station_docks
    ( 
        "Station ID" TEXT NOT NULL,
        "Empty Slots" INTEGER,
        "Available Bikes" INTEGER,
        "Total Slots" INTEGER,
        "Proportion of Available Bikes (%)" REAL
        CONSTRAINT fk_station_id
        FOREIGN KEY ("Station ID")
        REFERENCES station_locations("Station ID")
    );

    INSERT INTO station_docks SELECT * FROM station_docks_old;

    COMMIT;

    PRAGMA foreign_keys=on;
"""

# %%
con.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 con.close()
#
# NameError: name 'con' is not defined

# %%
bike_stations = pd.read_csv("df_stations.csv")
fs_locations = pd.read_csv("fs_df_with_totals.csv")

# %%
bike_stations.head(2)
# Out:
#    Empty Slots  Available Bikes                        Station ID   latitude  \
# 0           16               19  7a19c49f486d7c0c02b3685d7b240448  49.262487
# 1            3               13  32603a87cfca71d0f7dfa3513bad69d5  49.274566
#
#     longitude                      Station Name    Data Collection Timestamp  \
# 0 -123.114397                0001 10th & Cambie  2022-11-06T21:18:12.713000Z
# 1 -123.121817  0004 Yaletown-Roundhouse Station  2022-11-06T21:18:12.715000Z
#
#    Total Slots  Status
# 0           35  online
# 1           16  online

# %%
bike_stations["Proportion of Available Bikes (%)"] = round(bike_stations["Available Bikes"] / bike_stations["Total Slots"] * 100,0)

# %%
bike_station_cols = list(bike_stations.columns.values)
print(bike_station_cols)
# Out:
# ['Empty Slots', 'Available Bikes', 'Station ID', 'latitude', 'longitude', 'Station Name', 'Data Collection Timestamp', 'Total Slots', 'Status', 'Proportion of Available Bikes (%)']

# %%
bike_stations_for_db = bike_stations[['Station ID', 'Station Name', 'Available Bikes', 'Empty Slots', 'Total Slots', 'Proportion of Available Bikes (%)']]

# %%
bike_stations_for_db.head(2)
# Out:
#                          Station ID                      Station Name  \
# 0  7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie
# 1  32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station
#
#    Available Bikes  Empty Slots  Total Slots  \
# 0               19           16           35
# 1               13            3           16
#
#    Proportion of Available Bikes (%)
# 0                               54.0
# 1                               81.0

# %%
bike_stations_for_db = bike_stations_for_db.set_index("Station ID")

# %%
bike_stations_for_db.head(2)
# Out:
#                                                       Station Name  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                0001 10th & Cambie
# 32603a87cfca71d0f7dfa3513bad69d5  0004 Yaletown-Roundhouse Station
#
#                                   Available Bikes  Empty Slots  Total Slots  \
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448               19           16           35
# 32603a87cfca71d0f7dfa3513bad69d5               13            3           16
#
#                                   Proportion of Available Bikes (%)
# Station ID
# 7a19c49f486d7c0c02b3685d7b240448                               54.0
# 32603a87cfca71d0f7dfa3513bad69d5                               81.0

# %%
fs_locations.head(2)
# Out:
#                          Station ID   latitude   longitude  Bars - All  \
# 0  7a19c49f486d7c0c02b3685d7b240448  49.262487 -123.114397           1
# 1  32603a87cfca71d0f7dfa3513bad69d5  49.274566 -123.121817           7
#
#    Bars - Open  Restaurants - All  Restaurants - Open  Shopping - All  \
# 0            1                  7                   3               4
# 1            2                 25                  15              23
#
#    Shopping - Open  Education - All  Education - Open  \
# 0                1                1                 1
# 1               10                2                 0
#
#    Arts and Entertainment - All  Arts and Entertainment - Open  \
# 0                             1                              0
# 1                             3                              0
#
#    Total - All Venues  Total - Open Venues
# 0                  14                    6
# 1                  60                   27

# %%
fs_locations_cols = list(fs_locations.columns.values)
print(fs_locations_cols)
# Out:
# ['Station ID', 'latitude', 'longitude', 'Bars - All', 'Bars - Open', 'Restaurants - All', 'Restaurants - Open', 'Shopping - All', 'Shopping - Open', 'Education - All', 'Education - Open', 'Arts and Entertainment - All', 'Arts and Entertainment - Open', 'Total - All Venues', 'Total - Open Venues']

# %%
fs_locations_for_db = fs_locations[['latitude', 'longitude', 'Station ID', 'Bars - All', 'Bars - Open', 'Restaurants - All', 'Restaurants - Open', 'Shopping - All', 'Shopping - Open', 'Education - All', 'Education - Open', 'Arts and Entertainment - All', 'Arts and Entertainment - Open', 'Total - All Venues', 'Total - Open Venues']]

# %%
fs_locations_for_db.head(2)
# Out:
#     latitude   longitude                        Station ID  Bars - All  \
# 0  49.262487 -123.114397  7a19c49f486d7c0c02b3685d7b240448           1
# 1  49.274566 -123.121817  32603a87cfca71d0f7dfa3513bad69d5           7
#
#    Bars - Open  Restaurants - All  Restaurants - Open  Shopping - All  \
# 0            1                  7                   3               4
# 1            2                 25                  15              23
#
#    Shopping - Open  Education - All  Education - Open  \
# 0                1                1                 1
# 1               10                2                 0
#
#    Arts and Entertainment - All  Arts and Entertainment - Open  \
# 0                             1                              0
# 1                             3                              0
#
#    Total - All Venues  Total - Open Venues
# 0                  14                    6
# 1                  60                   27

# %%
fs_locations_for_db = fs_locations_for_db.set_index(["latitude", "longitude"])

# %%
fs_locations_for_db.head(2)
# Out:
#                                              Station ID  Bars - All  \
# latitude  longitude
# 49.262487 -123.114397  7a19c49f486d7c0c02b3685d7b240448           1
# 49.274566 -123.121817  32603a87cfca71d0f7dfa3513bad69d5           7
#
#                        Bars - Open  Restaurants - All  Restaurants - Open  \
# latitude  longitude
# 49.262487 -123.114397            1                  7                   3
# 49.274566 -123.121817            2                 25                  15
#
#                        Shopping - All  Shopping - Open  Education - All  \
# latitude  longitude
# 49.262487 -123.114397               4                1                1
# 49.274566 -123.121817              23               10                2
#
#                        Education - Open  Arts and Entertainment - All  \
# latitude  longitude
# 49.262487 -123.114397                 1                             1
# 49.274566 -123.121817                 0                             3
#
#                        Arts and Entertainment - Open  Total - All Venues  \
# latitude  longitude
# 49.262487 -123.114397                              0                  14
# 49.274566 -123.121817                              0                  60
#
#                        Total - Open Venues
# latitude  longitude
# 49.262487 -123.114397                    6
# 49.274566 -123.121817                   27

# %%
con = sqlite3.connect("stats_project_wk3.sqlite")

# %%
bike_stations_for_db.to_sql("bike_stations", con, if_exists="replace")
# Out:
# 240

# %%
fs_locations_for_db.to_sql("fs_locations", con, if_exists="replace")
# Out:
# 240

# %%
create_fk = """
CREATE TABLE fs_loc_with_fk
(
  "latitude" REAL NOT NULL,
  "longitude" REAL NOT NULL,
  "Station ID" TEXT NOT NULL,
  "Bars - All" INTEGER,
  "Bars - Open" INTEGER,
  "Restaurants - All" INTEGER,
  "Restaurants - Open" INTEGER,
  "Shopping - All" INTEGER,
  "Shopping - Open" INTEGER,
  "Education - All" INTEGER,
  "Education - Open" INTEGER,
  "Arts and Entertainment - All" INTEGER,
  "Arts and Entertainment - Open" INTEGER,
  "Total - All Venues" INTEGER,
  "Total - Open Venues" INTEGER,
    CONSTRAINT lat_long PRIMARY KEY ("latitude", "longitude"),
    CONSTRAINT fk_station_ids FOREIGN KEY ("Station ID") REFERENCES bike_stations ("Station ID")
);
"""

# %%
execute_query(con, create_fk)
# Out:
# Query executed successfully

# %%
create_pk = """
CREATE TABLE stations_with_pk
(
    "Station ID" TEXT NOT NULL PRIMARY KEY,
    "Station Name" TEXT,
    "Available Bikes" INTEGER,
    "Empty Slots" INTEGER,
    "Total Slots" INTEGER,
    "Proportion of Available Bikes (%)" REAL
)
"""

# %%
execute_query(con, create_pk)
# Out:
# Query executed successfully

# %%
drop_table_fs_loc_with_fk = """
    DROP TABLE fs_loc_with_fk
"""

# %%
execute_query(con, drop_table_fs_loc_with_fk)
# Out:
# Query executed successfully

# %%
create_fk = """
CREATE TABLE fs_loc_with_fk
(
  "latitude" REAL NOT NULL,
  "longitude" REAL NOT NULL,
  "Station ID" TEXT NOT NULL,
  "Bars - All" INTEGER,
  "Bars - Open" INTEGER,
  "Restaurants - All" INTEGER,
  "Restaurants - Open" INTEGER,
  "Shopping - All" INTEGER,
  "Shopping - Open" INTEGER,
  "Education - All" INTEGER,
  "Education - Open" INTEGER,
  "Arts and Entertainment - All" INTEGER,
  "Arts and Entertainment - Open" INTEGER,
  "Total - All Venues" INTEGER,
  "Total - Open Venues" INTEGER,
    CONSTRAINT lat_long PRIMARY KEY ("latitude", "longitude"),
    CONSTRAINT fk_station_ids FOREIGN KEY ("Station ID") REFERENCES stations_with_pk ("Station ID")
);
"""

# %%
execute_query(con, create_fk)
# Out:
# Query executed successfully

# %%
insert_into_station_table = """
INSERT INTO stations_with_pk SELECT * FROM bike_stations
"""

# %%
execute_query(con, insert_into_station_table)
# Out:
# Query executed successfully

# %%
insert_into_fs_table = """
INSERT INTO fs_loc_with_fk SELECT * FROM fs_locations
"""

# %%
execute_query(con, insert_into_fs_table)
# Out:
# Query executed successfully

# %%
drop_old_fs_table = """
    DROP TABLE fs_locations;
"""

# %%
execute_query(con, drop_old_fs_table)
# Out:
# Query executed successfully

# %%
drop_old_station_table = """
    DROP TABLE bike_stations;
"""

# %%
execute_query(con, drop_old_station_table)
# Out:
# Query executed successfully

# %%
rename_bike_table = """
    ALTER TABLE stations_with_pk RENAME TO bike_stations;
"""

# %%
execute_query(con, rename_bike_table)
# Out:
# Query executed successfully

# %%
rename_fs_table = """
    ALTER TABLE fs_loc_with_fk RENAME TO fs_locations;
"""

# %%
execute_query(con, rename_fs_table)
# Out:
# Query executed successfully

# %%
fs_df = pd.read_csv("fs_df_with_totals.csv")

# %%
fs_df.head(15)
# Out:
#                           Station ID   latitude   longitude  Bars - All  \
# 0   7a19c49f486d7c0c02b3685d7b240448  49.262487 -123.114397           1
# 1   32603a87cfca71d0f7dfa3513bad69d5  49.274566 -123.121817           7
# 2   6d42fa40360f9a6b2bf641c7b8bb2862  49.279764 -123.110154           1
# 3   66f873d641d448bd1572ab086665a458  49.260599 -123.113504           0
# 4   485d4d24c803cfde829ab89699fed833  49.264215 -123.117772           0
# 5   b07d513f87897cff7319a0e59d7e567c  49.270877 -123.115103           0
# 6   d1c9556d92f329703229fb3e33899a3b  49.268930 -123.118130           3
# 7   95e624191c655f50e401d280cd39a9ad  49.271721 -123.104207           0
# 8   3e112f9fe877e0003780386359060ae6  49.287214 -123.112870           1
# 9   6993b3dbb0758927967592ea612a2b1e  49.282409 -123.118541           1
# 10  bf8408067b0e0c963f3ff526977bcef3  49.287097 -123.118551           0
# 11  d2244f1a81d317c76cabd65e81250835  49.273471 -123.118016           0
# 12  0b543fc4e694fe07a54dac48bb1b3390  49.282758 -123.122092           1
# 13  1b4c6f63f4bfbbd983992dbdca776865  49.286042 -123.113176           0
# 14  fbb1d30d7f30b049873f5be5688563d4  49.286020 -123.116624           2
#
#     Bars - Open  Restaurants - All  Restaurants - Open  Shopping - All  \
# 0             1                  7                   3               4
# 1             2                 25                  15              23
# 2             1                  9                   6               3
# 3             0                  1                   0               1
# 4             0                  8                   4               7
# 5             0                  0                   0               1
# 6             2                  6                   3               1
# 7             0                  0                   0               0
# 8             0                 12                   6              10
# 9             1                 19                  12              50
# 10            0                 25                  11              19
# 11            0                  3                   0               5
# 12            0                 14                   6              42
# 13            0                  7                   3              18
# 14            2                 17                   7              26
#
#     Shopping - Open  Education - All  Education - Open  \
# 0                 1                1                 1
# 1                10                2                 0
# 2                 0                1                 0
# 3                 0                0                 0
# 4                 2                7                 0
# 5                 0                2                 0
# 6                 1                0                 0
# 7                 0                1                 0
# 8                 0                1                 0
# 9                47               15                 0
# 10                3                5                 0
# 11                3                0                 0
# 12               15                5                 1
# 13                4                4                 0
# 14                9               18                 2
#
#     Arts and Entertainment - All  Arts and Entertainment - Open  \
# 0                              1                              0
# 1                              3                              0
# 2                              2                              0
# 3                              0                              0
# 4                              0                              0
# 5                              0                              0
# 6                              0                              0
# 7                              1                              0
# 8                              2                              1
# 9                              0                              0
# 10                             2                              0
# 11                             0                              0
# 12                             2                              0
# 13                             2                              1
# 14                             2                              1
#
#     Total - All Venues  Total - Open Venues
# 0                   14                    6
# 1                   60                   27
# 2                   16                    7
# 3                    2                    0
# 4                   22                    6
# 5                    3                    0
# 6                   10                    6
# 7                    2                    0
# 8                   26                    7
# 9                   85                   60
# 10                  51                   14
# 11                   8                    3
# 12                  64                   22
# 13                  31                    8
# 14                  65                   21
